# %%
kor = 90
mat = 80
eng = 100

sum = kor + mat + eng
avg = sum/3

print("sum", sum)
print("avg", avg)
# Out:
# sum 270
# avg 90.0

# %%
print("T"*10)
print("T"*10)
print("    TT    ")
print("    TT    ")
print("    TT    ")
# Out:
# TTTTTTTTTT
# TTTTTTTTTT
#     TT
#     TT
#     TT

# %%
x = 10
y = 20
z = 30

print(x,"+",y,"=",z)
# Out:
# 10 + 20 = 30

# %%
x = input()
x = int(x)
y = input()
y = int(y)
z = input()
z = int(z)

sum = x + y + z
avg = sum//3

print("sum =", sum)
print("avg =", avg)
# Out:
# 20
# 50
# 100
# sum = 170
# avg = 56

# %%
double = input("yard? ")
double= float(double)

c = double * 91.44

print(double,"yard =",round(c,1),"cm",sep="")
# Out:
# yard? 10.1
# 10.1yard =923.5cm

# %%
x = input()
x = int(x)
y = input()
y = int(y)

a = x > y
b = x < y
c = x >= y
d = x <= y

print(a)
print(b)
print(c)
print(d)
# Out:
# 4
# 5
# False
# True
# False
# True

# %%
x = input()
x = int(x)
y = input()
y = int(y)
z = input()
z = int(z)

a = x > y and x > z
b = x == y == z

print(a)
print(b)
# Out:
# 10
# 10
# 10
# False
# True

# %%
x = input()
x = int(x)
y = input()
y = int(y)

a = x + 1
b = y - 1
mulit = a * b

print(a,b,mulit)
# Out:
# 10
# 20
# 11 19 209

# %%
#a, b = map(int, input(),split())
a, b = map(int, input().split())
c, d = map(int, input().split())

if (a>c and b>d):
  print("1")
else:
  print("0")
# Out:
# 150 35
# 145 35
# 0
